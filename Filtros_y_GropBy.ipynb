# %% [markdown]
# <a href="https://colab.research.google.com/github/brunobobadilla06/Bruno-CienciaDeDatos/blob/main/Filtros_y_GropBy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
# URL del archivo CSV
url = 'https://raw.githubusercontent.com/brunobobadilla06/Bruno-CienciaDeDatos/refs/heads/main/stocks_data.csv'
df_stockdata = pd.read_csv(url)
print(df_stockdata)
df_stockdata.head()
# Out:
#    formatted_date          MCD         SBUX         GOOG         AMZN  \
# 0      2016-01-01  1142.384153  2853.621490  2204.022007  1808.015698
# 1      2016-02-01   570.020153   574.711394   933.599462  1588.526602
# 2      2016-03-01  1789.471270   167.957726  1834.408210   536.456647
# 3      2016-04-01   132.133908  2730.681594   798.576545  1997.691185
# 4      2016-05-01   292.822731   612.069101   164.325048   996.231082
# ..            ...          ...          ...          ...          ...
# 66     2021-07-01  1292.884108    96.733846   827.971757  1638.653618
# 67     2021-08-01   379.720716  1742.253932   843.944005  1675.908667
# 68     2021-09-01   550.852698  2745.803479  1273.748459  1167.921429
# 69     2021-10-01  2165.566338   912.451495  1712.221782  1443.869695
# 70     2021-11-01  1022.704356  2319.609245   346.596812   253.159212
#
#            MSFT          JPM          BAC            C          MAR  \
# ...

# %%
# Mostrar informacion general del DatFrame
df_stockdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   formatted_date  71 non-null     object
#  1   MCD             71 non-null     float64
#  2   SBUX            71 non-null     float64
#  3   GOOG            71 non-null     float64
#  4   AMZN            71 non-null     float64
#  5   MSFT            71 non-null     float64
#  6   JPM             71 non-null     float64
#  7   BAC             71 non-null     float64
#  8   C               71 non-null     float64
#  9   MAR             71 non-null     float64
#  10  HLT             71 non-null     float64
#  11  RCL             71 non-null     float64
#  12  V               71 non-null     float64
#  13  MA              71 non-null     float64
#  14  PYPL            71 non-null     float64
# dtypes: float64(14), object(1)
# memory usage: 8.4+ KB

# %%
# Es buena practica convertir la columna Date a tipo datetime
#  Si Date no es de tipo datetime, muchas operaciones de tiempo fallaran o seran ineficientes
df_stockdata['formatted_date'] = pd.to_datetime(df_stockdata['formatted_date'])
df_stockdata.info()

#  Saber el tipo de datos
df_stockdata.dtypes['formatted_date']
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   formatted_date  71 non-null     datetime64[ns]
#  1   MCD             71 non-null     float64
#  2   SBUX            71 non-null     float64
#  3   GOOG            71 non-null     float64
#  4   AMZN            71 non-null     float64
#  5   MSFT            71 non-null     float64
#  6   JPM             71 non-null     float64
#  7   BAC             71 non-null     float64
#  8   C               71 non-null     float64
#  9   MAR             71 non-null     float64
#  10  HLT             71 non-null     float64
#  11  RCL             71 non-null     float64
#  12  V               71 non-null     float64
#  13  MA              71 non-null     float64
#  14  PYPL            71 non-null     float64
# dtypes: datetime64[ns](1), float64(14)
# memory usage: 8.4 KB
# dtype('<M8[ns]')

# %%
# VER LAS DIMENSIONES DEL DATAFRAME(FILAS, COLUMNAS)
print(f"\nDimensiones del data Frame: {df_stockdata.shape}")
# Out:
# Dimensiones del data Frame: (71, 15)

# %%
# Ver las columnas
print(f"\nColumnas del data Frame: {df_stockdata.columns.to_list()}")
# Out:
# Columnas del data Frame: ['formatted_date', 'MCD', 'SBUX', 'GOOG', 'AMZN', 'MSFT', 'JPM', 'BAC', 'C', 'MAR', 'HLT', 'RCL', 'V', 'MA', 'PYPL']

# %%
# Filtrado con indices booleanos
import pandas as pd
# URL del archivo CSV
url = 'https://raw.githubusercontent.com/brunobobadilla06/Bruno-CienciaDeDatos/refs/heads/main/stocks_data.csv'
df_stockdata = pd.read_csv(url)

df_stockdata['formatted_date'] = pd.to_datetime(df_stockdata['formatted_date'])
condicion_fecha = df_stockdata['formatted_date'] >= pd.Timestamp('2016-03-01')
df_desde_marzo = df_stockdata[condicion_fecha]
print(df_desde_marzo)


#Filtrado por fecha
condicion_fecha = df_stockdata['formatted_date'] >= pd.Timestamp('2016-03-01')
def_desde_marzo = df_stockdata[condicion_fecha]
# Out:
#    formatted_date          MCD         SBUX         GOOG         AMZN  \
# 2      2016-03-01  1789.471270   167.957726  1834.408210   536.456647
# 3      2016-04-01   132.133908  2730.681594   798.576545  1997.691185
# 4      2016-05-01   292.822731   612.069101   164.325048   996.231082
# 5      2016-06-01  2323.566965   620.185574    46.400688  2451.920443
# 6      2016-07-01   953.617495   995.794466  2196.930350  1923.545690
# ..            ...          ...          ...          ...          ...
# 66     2021-07-01  1292.884108    96.733846   827.971757  1638.653618
# 67     2021-08-01   379.720716  1742.253932   843.944005  1675.908667
# 68     2021-09-01   550.852698  2745.803479  1273.748459  1167.921429
# 69     2021-10-01  2165.566338   912.451495  1712.221782  1443.869695
# 70     2021-11-01  1022.704356  2319.609245   346.596812   253.159212
#
#            MSFT          JPM          BAC            C          MAR  \
# ...

# %%
# Filtrar por tickets especificos
condicion_goog_alto = df_stockdata['GOOG'] > 2500
df_goog_alto = df_stockdata[condicion_goog_alto]
print(df_goog_alto)
# Out:
#    formatted_date          MCD         SBUX         GOOG         AMZN  \
# 14     2017-03-01  2186.088366  2694.417472  2664.646680  2346.230371
# 16     2017-05-01   817.651032   754.649241  2919.841348  1197.500242
# 17     2017-06-01  1947.052719   556.018718  2823.161996  2863.167874
# 23     2017-12-01  1990.786209   861.403674  2865.949884  2221.553843
# 26     2018-03-01  2826.150482  1176.724834  2884.735975  2718.891407
# 29     2018-06-01  1185.928986    62.187825  2718.984470   301.121430
# 33     2018-10-01  2245.753291  1762.605232  2887.652469  1143.365621
# 34     2018-11-01   249.175797  1674.947225  2908.828531  1583.600597
# 36     2019-01-01  2063.651582   512.972310  2735.453738  2472.935611
# 54     2020-07-01  1871.616085  1614.379443  2684.860972  2372.133717
# 58     2020-11-01   400.248163  2764.900391  2613.592195  1570.949030
#
#            MSFT          JPM          BAC            C          MAR  \
# ...

# %%
import pandas as pd
# URL del archivo CSV
url = 'https://raw.githubusercontent.com/brunobobadilla06/Bruno-CienciaDeDatos/refs/heads/main/stocks_data.csv'
df_stockdata = pd.read_csv(url)

df_stockdata['formatted_date'] = pd.to_datetime(df_stockdata['formatted_date'])
condicion_fecha = df_stockdata['formatted_date'] >= pd.Timestamp('2016-03-01')
df_desde_marzo = df_stockdata[condicion_fecha]


# Codicion multiple
df_combo1 = df_stockdata[(df_stockdata['GOOG'] > 700) & (df_stockdata['MSFT'] < 1000)]
print(df_combo1)
# Out:
#    formatted_date          MCD         SBUX         GOOG         AMZN  \
# 0      2016-01-01  1142.384153  2853.621490  2204.022007  1808.015698
# 2      2016-03-01  1789.471270   167.957726  1834.408210   536.456647
# 3      2016-04-01   132.133908  2730.681594   798.576545  1997.691185
# 10     2016-11-01  2888.468466   777.793419  1506.828063   923.608580
# 11     2016-12-01  2957.381849   748.904156  2026.242576  2292.010258
# 22     2017-11-01  2391.702998   834.371786  1333.745119   263.015453
# 25     2018-02-01  1524.314688  2573.774828  1986.320086   513.915248
# 26     2018-03-01  2826.150482  1176.724834  2884.735975  2718.891407
# 29     2018-06-01  1185.928986    62.187825  2718.984470   301.121430
# 33     2018-10-01  2245.753291  1762.605232  2887.652469  1143.365621
# 44     2019-09-01   211.401541   852.326615  2424.417801  2252.331280
# 45     2019-10-01  2148.648270  2688.764308  1549.682003  1610.377051
# ...

# %%
condicion_marzo = df_stockdata['formatted_date'] >= '2016-03-01'
condicion_amazon_alto = df_stockdata['AMZN'] > 2500
df_combo2 = df_stockdata[condicion_marzo | condicion_amazon_alto]
print(df_combo2)
# Out:
#    formatted_date          MCD         SBUX         GOOG         AMZN  \
# 2      2016-03-01  1789.471270   167.957726  1834.408210   536.456647
# 3      2016-04-01   132.133908  2730.681594   798.576545  1997.691185
# 4      2016-05-01   292.822731   612.069101   164.325048   996.231082
# 5      2016-06-01  2323.566965   620.185574    46.400688  2451.920443
# 6      2016-07-01   953.617495   995.794466  2196.930350  1923.545690
# ..            ...          ...          ...          ...          ...
# 66     2021-07-01  1292.884108    96.733846   827.971757  1638.653618
# 67     2021-08-01   379.720716  1742.253932   843.944005  1675.908667
# 68     2021-09-01   550.852698  2745.803479  1273.748459  1167.921429
# 69     2021-10-01  2165.566338   912.451495  1712.221782  1443.869695
# 70     2021-11-01  1022.704356  2319.609245   346.596812   253.159212
#
#            MSFT          JPM          BAC            C          MAR  \
# ...

# %%
# Agrupacion con groupby()
# Necesitamos extraer componentes de la fecha (Año, Mes, Trimestre) para agrupar
df_stockdata['year'] = df_stockdata['formatted_date'].dt.year
df_stockdata['month'] = df_stockdata['formatted_date'].dt.month
df_stockdata['quarter'] = df_stockdata['formatted_date'].dt.quarter

df_stockdata.head(10)
# Out:
#   formatted_date          MCD         SBUX         GOOG         AMZN  \
# 0     2016-01-01  1142.384153  2853.621490  2204.022007  1808.015698
# 1     2016-02-01   570.020153   574.711394   933.599462  1588.526602
# 2     2016-03-01  1789.471270   167.957726  1834.408210   536.456647
# 3     2016-04-01   132.133908  2730.681594   798.576545  1997.691185
# 4     2016-05-01   292.822731   612.069101   164.325048   996.231082
# 5     2016-06-01  2323.566965   620.185574    46.400688  2451.920443
# 6     2016-07-01   953.617495   995.794466  2196.930350  1923.545690
# 7     2016-08-01   105.494806   350.437538   123.344681  1920.138921
# 8     2016-09-01  2791.202027  2430.117527  1911.209157  2618.237953
# 9     2016-10-01  2459.503855  2586.369832    50.647828  1546.919489
#
#           MSFT          JPM          BAC            C          MAR  \
# 0   493.375362   493.303725   202.508328  2602.543153  1815.311585
# 1  1312.876705   894.950546  1847.203097   444.296766   897.669606
# ...

# %%
ticker_cols = ['MCD', 'SBUX', 'GOOG', 'AMZN', 'MSFT', 'JPM', 'BAC', 'C', 'MAR', 'HLT', 'RCL', 'V', 'MA', 'PYPL']

# CALCULAR EL PRECIO PROMEDIO ANUAL PARA CADA TICKETS
# Agrupamos por año, y luego calculamos la media de todas las columnas numericas
promedio_anual = df_stockdata.groupby('year')[ticker_cols].mean()
promedio_anual.head(15)
# Out:
#               MCD         SBUX         GOOG         AMZN         MSFT  \
# year
# 2016  1533.838973  1287.386985  1149.711218  1716.941879  1268.834224
# 2017  1804.930096  1492.415311  1875.463930  1268.562370  2014.165032
# 2018  1614.790399  1600.832842  1665.574214  1476.804462  1300.040587
# 2019  1562.967591  1410.188407  1417.195157  1987.548970  1566.252782
# 2020  1159.219380  1745.392282  1679.092803  1686.602691  1137.716802
# 2021  1043.795619  1555.575666  1018.056324  1220.021142  1640.781979
#
#               JPM          BAC            C          MAR          HLT  \
# year
# 2016  1285.097300  1712.806759  1367.539270  1617.312686  1504.196184
# 2017  1343.280802  1436.322995  1643.784516  1456.501425  1824.998160
# 2018  1736.936332  1177.508790  1813.186731  1207.500218  1816.055636
# 2019  1420.429739  1464.899190  1410.024538  1763.043543  1378.920654
# 2020  1633.259988  1330.344947  1737.977716  1331.215126  1816.750847
# ...
